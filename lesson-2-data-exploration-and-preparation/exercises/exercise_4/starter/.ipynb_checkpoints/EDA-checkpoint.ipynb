# %%
import seaborn as sns
import pandas as pd
import wandb
from pandas_profiling import ProfileReport
#import matplotlib.pyplot as plt
# %matplotlib inline

# %%
run = wandb.init(
  project="eda",
  save_code=True
)
# Out:
# wandb: Currently logged in as: nikohunt (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.13.3 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.21<br/>
#                 Syncing run <strong style="color:#cdcd00">dry-violet-3</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/nikohunt/eda" target="_blank">https://wandb.ai/nikohunt/eda</a><br/>
#                 Run page: <a href="https://wandb.ai/nikohunt/eda/runs/19tcpul0" target="_blank">https://wandb.ai/nikohunt/eda/runs/19tcpul0</a><br/>
#                 Run data is saved locally in <code>/Users/Nikolas.Hunt/Source/cd0581/lesson-2-data-exploration-and-preparation/exercises/exercise_4/starter/wandb/run-20220918_085619-19tcpul0</code><br/><br/>

# %%
artifact = run.use_artifact("genres_mod.parquet:latest")
df = pd.read_parquet(artifact.file())
df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.831   0.814    2    -7.364     1       0.4200        0.0598
# 1         0.719   0.493    8    -7.230     1       0.0794        0.4010
# 2         0.850   0.893    5       NaN     1       0.0623        0.0138
# 3         0.476   0.781    0    -4.710     1       0.1030        0.0237
# 4         0.798   0.624    2    -7.668     1       0.2930        0.2170
#
#    instrumentalness  liveness  valence    tempo            type  duration_ms  \
# 0          0.013400    0.0556   0.3890  156.985  audio_features       124539
# 1          0.000000    0.1180   0.1240  115.080  audio_features       224427
# 2          0.000004    0.3720   0.0391  218.050  audio_features        98821
# 3          0.000000    0.1140   0.1750  186.948  audio_features       123661
# 4          0.000000    0.1660   0.5910  147.988  audio_features       123298
#
#    time_signature      genre                                      song_name  \
# 0               4  Dark Trap                            Mercury: Retrograde
# 1               4  Dark Trap                                      Pathology
# 2               4  Dark Trap                                       Symbiote
# 3               3  Dark Trap  ProductOfDrugs (Prod. The Virus and Antidote)
# 4               4  Dark Trap                                          Venom
#
#   title
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None

# %%
profile = ProfileReport(df, title="Pandas Profiling Report", explorative=True)
profile.to_widgets()
# Out:
# Summarize dataset:   0%|          | 0/30 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %% [markdown]
# Remove duplicates

# %%
df = df.drop_duplicates().reset_index(drop=True)

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Concatenate Song Title

# %%
df['title'].fillna(value='', inplace=True)
df['song_name'].fillna(value='', inplace=True)
df['text_feature'] = df['title'] + ' ' + df['song_name']

# %%
sns.histplot(df.danceability)
# Out:
# <AxesSubplot: xlabel='danceability', ylabel='Count'>

# %%
sns.histplot(df.energy)
# Out:
# <AxesSubplot: xlabel='energy', ylabel='Count'>

# %%
sns.countplot(x=df.key)
# Out:
# <AxesSubplot: xlabel='key', ylabel='count'>

# %%
sns.scatterplot(x=df.danceability, y=df.energy, alpha=0.02)
# Out:
# <AxesSubplot: xlabel='danceability', ylabel='energy'>

# %%
run.finish()
# Out:
# <br/>Waiting for W&B process to finish, PID 31170<br/>Program ended successfully.
# VBox(children=(Label(value=' 3.16MB of 3.16MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
